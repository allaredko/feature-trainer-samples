# %% [markdown]
# ## Write a formula
#
# $$c = \sqrt(a^2 + b^2)$$

# %% [markdown]
# ## Draw a scatter chart

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 20
x = np.random.rand(N)
print('X-axis values:\n', x)
y = np.random.rand(N)
print('Y-axis values:\n', y)
# Out:
# X-axis values:
#  [0.91670259 0.57630809 0.78586482 0.85170883 0.43635328 0.64421064
#  0.09278715 0.68178694 0.9180837  0.7712612  0.12006263 0.55615398
#  0.19924243 0.00822069 0.09219614 0.41352182 0.30504054 0.2278845
#  0.89459911 0.65025512]
# Y-axis values:
#  [0.22340837 0.05296909 0.91282029 0.14507034 0.69957252 0.35444828
#  0.49581366 0.58366055 0.63965066 0.56802408 0.98050601 0.44440978
#  0.49934865 0.67811482 0.65568864 0.70082425 0.97940583 0.46555914
#  0.67995575 0.99484611]

# %%
colors = np.random.rand(N)
area = np.pi * (30 * np.random.rand(N))**2  # 0 to 15 point radii
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
# ?plt.scatter
plt.show()

# %%
import pandas
sample_data_frame = pandas.DataFrame(
    {'month': ["Jan", "Feb", "May"], 
     'average value': [3.2, 5.2, 6.5]}
)
print(sample_data_frame)
# Out:
#   month  average value
# 0   Jan            3.2
# 1   Feb            5.2
# 2   May            6.5
